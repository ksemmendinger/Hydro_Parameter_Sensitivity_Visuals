# %%
# %load test01.py
#!/usr/bin/env python3
"""
Created on Wed Jun 19 11:20:34 2019

@author: catiefinkenbiner
"""

def helloworld():
    print('hello world!')

# %%
helloworld()

# %%
# %run dummy_data.py
